# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import seaborn as sns
import loompy
import anndata

sc.settings.verbosity = 3     
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
adata=sc.read_h5ad('mergedata_20200930_high_quality.h5ad')
#adata = sc.read_loom('good.loom', X_name='spliced', obs_names='cellID', var_names='GeneName', dtype='float32',validate=False)
adata.obs_names_make_unique() 
adata
# Out:
# scanpy==1.6.0 anndata==0.7.4 umap==0.4.5 numpy==1.19.1 scipy==1.5.2 pandas==1.1.1 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.2 louvain==0.7.0 leidenalg==0.8.1
# AnnData object with n_obs × n_vars = 106806 × 37907
#     obs: 'Age', 'Condition', 'DENV_reads', 'Gender', 'ID', 'cell_quality', 'cell_subtype', 'cell_type', 'doublets', 'n_counts', 'n_genes', 'platform'
#     var: 'feature_types_10X', 'feature_types_plate'

# %%
adata=adata[adata.obs['cell_quality']=='high']
sc.pp.log1p(adata)
adata_children=adata[adata.obs['platform']=='10X']
adata_adults=adata[adata.obs['platform']=='plate']
# Out:
# /usr/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /usr/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py:339: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
#'Age'：共16个病人，11个儿童，5个成年人
#'Condition'：S_dengue,dengue,Healthy,DWS
#'cell_subtype'：unknown, naive_B, CD14+CD16-mono, CD4-CD8+t, memory_B, CD16+CD14+mono, CD4+CD8-t, CD14-CD16+mono, CD4+CD8+t
#'cell_type'：NK_cells, B_cells, T_cells, Monocytes, Plasmablasts, pDCs, cDCs

# %%
# interaction between different celltypes within children SD patients
interaction=pd.read_csv('interaction_unpacked_mouse.tsv',sep='\t')[['gene_name_a','gene_name_b']]

# %%
#Condition of children
adata_children_conditions={}
Conditions=['S_dengue','dengue','Healthy','DWS']

for Condition in Conditions:
    adata_children_conditions[Condition]=adata_children[adata_children.obs['Condition']==Condition]

adata_children_conditions.keys()
# Out:
# dict_keys(['S_dengue', 'dengue', 'Healthy', 'DWS'])

# %%
#celltypes of children with different conditions
adata_children_con_ct={}
cell_types=['B_cells','NK_cells','T_cells', 'Monocytes', 'Plasmablasts', 'pDCs', 'cDCs']
Conditions=['S_dengue','dengue','Healthy','DWS']

for Condition in Conditions:
    for cell_type in cell_types:
        key=(Condition,cell_type)
        adata_children_con_ct[key]=adata_children_conditions[Condition][adata_children_conditions[Condition].obs['cell_type']==cell_type]

adata_children_con_ct.keys()
# Out:
# dict_keys([('S_dengue', 'B_cells'), ('S_dengue', 'NK_cells'), ('S_dengue', 'T_cells'), ('S_dengue', 'Monocytes'), ('S_dengue', 'Plasmablasts'), ('S_dengue', 'pDCs'), ('S_dengue', 'cDCs'), ('dengue', 'B_cells'), ('dengue', 'NK_cells'), ('dengue', 'T_cells'), ('dengue', 'Monocytes'), ('dengue', 'Plasmablasts'), ('dengue', 'pDCs'), ('dengue', 'cDCs'), ('Healthy', 'B_cells'), ('Healthy', 'NK_cells'), ('Healthy', 'T_cells'), ('Healthy', 'Monocytes'), ('Healthy', 'Plasmablasts'), ('Healthy', 'pDCs'), ('Healthy', 'cDCs'), ('DWS', 'B_cells'), ('DWS', 'NK_cells'), ('DWS', 'T_cells'), ('DWS', 'Monocytes'), ('DWS', 'Plasmablasts'), ('DWS', 'pDCs'), ('DWS', 'cDCs')])

# %%
#Condition of adults
adata_adults_conditions={}
Conditions=['S_dengue','dengue','Healthy','DWS']

for Condition in Conditions:
    adata_adults_conditions[Condition]=adata_adults[adata_adults.obs['Condition']==Condition]

adata_adults_conditions.keys()
# Out:
# dict_keys(['S_dengue', 'dengue', 'Healthy', 'DWS'])

# %%
#celltypes of adults with different conditions
adata_adults_con_ct={}
cell_types=['B_cells','NK_cells','T_cells', 'Monocytes', 'Plasmablasts', 'pDCs', 'cDCs']
Conditions=['S_dengue','dengue','Healthy','DWS']

for Condition in Conditions:
    for cell_type in cell_types:
        key=(Condition,cell_type)
        adata_adults_con_ct[key]=adata_adults_conditions[Condition][adata_adults_conditions[Condition].obs['cell_type']==cell_type]

adata_adults_con_ct.keys()
# Out:
# dict_keys([('S_dengue', 'B_cells'), ('S_dengue', 'NK_cells'), ('S_dengue', 'T_cells'), ('S_dengue', 'Monocytes'), ('S_dengue', 'Plasmablasts'), ('S_dengue', 'pDCs'), ('S_dengue', 'cDCs'), ('dengue', 'B_cells'), ('dengue', 'NK_cells'), ('dengue', 'T_cells'), ('dengue', 'Monocytes'), ('dengue', 'Plasmablasts'), ('dengue', 'pDCs'), ('dengue', 'cDCs'), ('Healthy', 'B_cells'), ('Healthy', 'NK_cells'), ('Healthy', 'T_cells'), ('Healthy', 'Monocytes'), ('Healthy', 'Plasmablasts'), ('Healthy', 'pDCs'), ('Healthy', 'cDCs'), ('DWS', 'B_cells'), ('DWS', 'NK_cells'), ('DWS', 'T_cells'), ('DWS', 'Monocytes'), ('DWS', 'Plasmablasts'), ('DWS', 'pDCs'), ('DWS', 'cDCs')])

# %%
#genes_interested={'':['MIF','CD74'],'NK_cells':['HLA-E','KLRC1','KLRD1']}

genes_interested=['MIF','CD74','HLA-E','KLRC1','KLRD1','LTB','LTBR']
genes_interested_all=['MIF','CD74','HLA-E','KLRC1','KLRD1','TNFRSF14','TNFRSF13B',
                  'TNFSF13','TGFBR2','TGFB1','SELL','CD34','LAMP1','FAM3C','ITGB2','ICAM2','LTB','LTBR']

# %%
fig,axs=plt.subplots(1,2,figsize=(12,4),gridspec_kw={'wspace':0.3})
ax=axs[0]
sc.pl.dotplot(adata_children_conditions['S_dengue'],genes_interested,groupby='cell_type',ax=ax,show=False,cmap='bwr')
ax.set_title('children',y=0.75)
ax=axs[1]
sc.pl.dotplot(adata_adults_conditions['S_dengue'],genes_interested,groupby='cell_type',ax=ax,show=False,cmap='bwr')
ax.set_title('adults',y=0.75)
plt.tight_layout()
# Out:
# /usr/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# <ipython-input-10-537a132fbd9f>:8: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(16,4),gridspec_kw={'wspace':0.3})
ax1=sc.pl.dotplot(adata_children_conditions['S_dengue'],genes_interested_all,groupby='cell_type',ax=ax1,show=False,cmap='bwr',title='children')
ax2=sc.pl.dotplot(adata_adults_conditions['S_dengue'],genes_interested_all,groupby='cell_type',ax=ax2,show=False,cmap='bwr',title='adults')
# Out:
# /usr/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /usr/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):

# %%
genes_interested_both=['SELL','SELPLG','CD22','PTPRC','CD55','ADGRE5','ICAM2','ITGAL','ITGB2']
fig,axs=plt.subplots(1,2,figsize=(12,4),gridspec_kw={'wspace':0.3})
ax=axs[0]
sc.pl.dotplot(adata_children_conditions['S_dengue'],genes_interested_both,groupby='cell_type',ax=ax,show=False,cmap='bwr')
ax.set_title('children',y=0.75)
ax=axs[1]
sc.pl.dotplot(adata_adults_conditions['S_dengue'],genes_interested_both,groupby='cell_type',ax=ax,show=False,cmap='bwr')
ax.set_title('adults',y=0.75)
plt.tight_layout()
# Out:
# /usr/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /usr/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# <ipython-input-12-69ffb3462e13>:9: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Out:
# 11    26642
# 16    17422
# 13    14416
# 5     10344
# 4      6266
# 15     5490
# 12     4777
# 8      4168
# 17     4145
# 6      3861
# Name: Age, dtype: int64

# %%
fig,axs=plt.subplots(1,2,figsize=(12,4),gridspec_kw={'wspace':0.3})
ax=axs[0]
sc.pl.dotplot(adata_children,genes_interested,groupby='Condition',ax=ax,show=False,cmap='bwr')
ax.set_title('children',y=0.75)
ax=axs[1]
sc.pl.dotplot(adata_adults,genes_interested,groupby='Condition',ax=ax,show=False,cmap='bwr')
ax.set_title('adults',y=0.75)
plt.tight_layout()
# Out:
# /usr/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /usr/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# <ipython-input-14-d01455704f68>:8: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
