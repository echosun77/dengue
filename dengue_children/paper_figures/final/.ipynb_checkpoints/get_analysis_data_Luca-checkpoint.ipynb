# %%
import os

import numpy as np
import pandas as pd

import anndata
import scanpy as sc

import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from matplotlib.collections import PatchCollection
from matplotlib import gridspec
import matplotlib as mpl
import seaborn as sns

from collections import defaultdict
import random
import itertools
from numpy import *

# %%
import sys
sys.path.append('/home/yike/phd/dengue/dengue_children/paper_figures/final/modules') 
import YK_util, optimized_pair_comparison, functions_CCC_figure_fra_pair
from YK_util import *
from optimized_pair_comparison import *
from functions_CCC_figure_fra_pair import *

# %%
def annanote_adult(adata_adult): 
    adata_adult.obs['cell_type_new'] = adata_adult.obs['cell_type']
    adata_adult.obs['cell_type_new'] = adata_adult.obs['cell_type_new'].astype('object')
    adata_adult.obs['cell_subtype_new'] = adata_adult.obs['cell_subtype_new'].astype('object')
    
    adata_adult.obs.loc[adata_adult.obs['cell_type_new'] == 'NK_cells', 'cell_type_new'] = 'NK cells'
    adata_adult.obs.loc[adata_adult.obs['cell_type_new'] == 'B_cells', 'cell_type_new'] = 'B cells'
    adata_adult.obs.loc[adata_adult.obs['cell_type_new'] == 'T_cells', 'cell_type_new'] = 'T cells'
    ####################################
    
    for gene in ['GZMA',  'NKG7', 'GNLY', 'XCL1', 'XCL2', 'FCGR3A', 'CCND2', 'MKI67']:
            adata_adult.obs[gene] = (adata_adult[:, gene].X.toarray() > 0)
    
    ####################  
    adata_adult.obs.loc[adata_adult.obs['cell_type_new'] == 'NK cells', 'cell_type_new'] = 'NK_unknown'
    idx_NK = ((adata_adult.obs['cell_type_new'] == 'NK_unknown') &
             (adata_adult.obs['GZMA'] == True) &
             (adata_adult.obs['NKG7'] == True) &
             (adata_adult.obs['GNLY'] == True) )
    adata_adult.obs.loc[idx_NK, 'cell_type_new'] = 'NK cells'
    
    adata_adult.obs.loc[adata_adult.obs['cell_type_new'] == 'NK cells', 'cell_subtype_new'] = 'cytotoxic NK cells'
    idx_sig_NK = ((adata_adult.obs['cell_type_new'] == 'NK cells') & 
                        (adata_adult.obs['XCL1'] == True) & 
                        (adata_adult.obs['XCL2'] == True) &
                        (adata_adult.obs['FCGR3A'] == True))
    adata_adult.obs.loc[idx_sig_NK, 'cell_subtype_new'] = 'signaling NK cells'
    
    ####################
    adata_adult.obs.loc[adata_adult.obs['cell_type_new'] == 'Plasmablasts', 'cell_subtype_new'] = 'non-proliferating plasmablasts'
    idx_P = ((adata_adult.obs['cell_type_new'] == 'Plasmablasts') & 
                        (adata_adult.obs['CCND2'] == True) & 
                        (adata_adult.obs['MKI67'] == True))
    adata_adult.obs.loc[idx_P, 
                        'cell_subtype_new'] = 'proliferating plasmablasts'
    
    ####################
    adata_adult.obs['cell_type_new'] = adata_adult.obs['cell_type_new'].astype('category')
    adata_adult.obs['cell_subtype_new'] = adata_adult.obs['cell_subtype_new'].astype('category')    
    return adata_adult

# %%
path = '/home/yike/phd/dengue/data/mergedata_luca_NKT_202206.h5ad'
adata = sc.read_h5ad(path)
adata_kid = subsetdata(adata)
adata_kid = normalizedata(adata_kid, log1p=True) # log1p = 2
adata_kid = removegenes(adata_kid)
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)

# %%
save_tables = '/home/yike/phd/dengue/docs/paper_draft/tabels/'
# save_figures = '/home/yike/phd/dengue/figures/paper_figure/dataset_20211001/'

# %% [markdown]
# # kids

# %%
# #pair comparison generation for cell types of kids 
cts = adata_kid.obs['cell_type_new'].unique().tolist()
cts.remove('doublets')
cts.remove('unknown')

pair = pair_comparison(adata_kid, 'cell_type_new', cts, gene_cut_off=False, log1p=2)

pair['pair_res'].to_csv(save_tables + 'ct_pair.tsv', sep='\t', index=False)
pair['log_FCs'].to_csv(save_tables + 'ct_log2FC.tsv', sep='\t')

fra_av = fra_avg(adata_kid, cts, log1p=2)
fra_av['fra'].to_csv(save_tables + 'ct_fra.tsv', sep='\t', index=False)
fra_av['avg'].to_csv(save_tables + 'ct_avg.tsv', sep='\t', index=False)

data = combination(pair['pair_res'], fra_av['fra'], fra_av['avg'])
data.to_csv(save_tables + 'ct_pair.tsv', sep='\t')
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# ...

# %%
#pair comparison generation for cell subtypes of kids
csts = adata_kid.obs['cell_subtype_new'].unique().tolist()
csts.remove('doublets')
csts.remove('megakaryocytes')
csts.remove('pDCs')
#csts.remove('conventional DCs')
csts.remove('unknown')

pair = pair_comparison(adata_kid, 'cell_subtype_new', csts, gene_cut_off=False, log1p=2)

pair['pair_res'].to_csv(save_tables + 'cst_pair.tsv', sep='\t', index=False)
pair['log_FCs'].to_csv(save_tables + 'cst_log2FC.tsv', sep='\t')

fra_av = fra_avg(adata_kid, csts, log1p=2)
fra_av['fra'].to_csv(save_tables + 'cst_fra.tsv', sep='\t', index=False)
fra_av['avg'].to_csv(save_tables + 'cst_avg.tsv', sep='\t', index=False)

data = combination(pair['pair_res'], fra_av['fra'], fra_av['avg'])
data.to_csv(save_tables + 'cst_pair.tsv', sep='\t')
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# ...

# %%
ct_fra = pd.read_csv(save_tables + 'ct_fra.tsv', sep='\t', index_col=['cell_type_new', 'gene', 'condition'])
ct_avg = pd.read_csv(save_tables + 'ct_avg.tsv', sep='\t', index_col=['cell_type_new', 'gene', 'condition'])

cst_fra = pd.read_csv(save_tables + 'cst_fra.tsv', sep='\t', index_col=['cell_subtype_new', 'gene', 'condition'])
cst_avg = pd.read_csv(save_tables + 'cst_avg.tsv', sep='\t', index_col=['cell_subtype_new', 'gene', 'condition'])

ct_pair = pd.read_csv(save_tables + 'ct_pair.tsv', sep='\t', index_col=['cell_subtype', 'gene'])
ct_log2FC = pd.read_csv(save_tables + 'ct_log2FC.tsv', sep='\t', index_col=0)

cst_pair = pd.read_csv(save_tables + 'cst_pair.tsv', sep='\t', index_col=['cell_subtype', 'gene'])
cst_log2FC = pd.read_csv(save_tables + 'cst_log2FC.tsv', sep='\t', index_col=0)

# %%
cst_pair = pd.concat([cst_pair, ct_pair.loc[['megakaryocytes', 'plasmacytoid DCs']]])
cst_log2FC = pd.concat([cst_log2FC, ct_log2FC.loc[['megakaryocytes','plasmacytoid DCs']]])
cst_fra = pd.concat([cst_fra, ct_fra.loc[['megakaryocytes', 'plasmacytoid DCs']]])
cst_avg = pd.concat([cst_avg, ct_avg.loc[['megakaryocytes', 'plasmacytoid DCs']]])

# %%
cst_log2FC = cst_log2FC.reset_index()
cst_log2FC['index'] = cst_log2FC['index'].replace({'plasmacytoid DCs': 'pDCs'})

cst_fra = cst_fra.reset_index()
cst_fra['cell_subtype_new'] = cst_fra['cell_subtype_new'].replace({'plasmacytoid DCs': 'pDCs'})

cst_avg = cst_avg.reset_index()
cst_avg['cell_subtype_new'] = cst_avg['cell_subtype_new'].replace({'plasmacytoid DCs': 'pDCs'})

cst_pair.to_csv(save_tables + 'cst_pair.tsv', sep='\t')
cst_log2FC.to_csv(save_tables + 'cst_log2FC.tsv', sep='\t')
cst_fra.to_csv(save_tables + 'cst_fra.tsv', sep='\t')
cst_avg.to_csv(save_tables + 'cst_avg.tsv', sep='\t')

ct_pair['log2_fold_change'] = np.log2(ct_pair['S_avg'] + 1) - np.log2(ct_pair['NS_avg'] + 1)
cst_pair['log2_fold_change'] = np.log2(cst_pair['S_avg'] + 1) - np.log2(cst_pair['NS_avg'] + 1)
ct_pair.to_csv(save_tables + 'ct_pair.tsv', sep='\t')
cst_pair.to_csv(save_tables + 'cst.tsv', sep='\t')

# %%
import anndataks
cts = adata_kid.obs['cell_type_new'].unique().tolist()
cts.remove('doublets')
cts.remove('unknown')

csts = adata_kid.obs['cell_subtype_new'].unique().tolist()
csts.remove('doublets')
csts.remove('megakaryocytes')
csts.remove('pDCs')
# csts.remove('conventional DCs')
csts.remove('unknown')

subcts = cts + csts
conditions = ['S_dengue', 'dengue']

results = {}
for subct in subcts:
    if subct in adata_kid.obs['cell_type_new'].astype('category').cat.categories:
        adata_ct = adata_kid[adata_kid.obs['cell_type_new'] == subct]
    elif subct in adata_kid.obs['cell_subtype_new'].astype('category').cat.categories:
        adata_ct = adata_kid[adata_kid.obs['cell_subtype_new'] == subct]
        
    adata_SD = adata_ct[adata_ct.obs['Condition'] == 'S_dengue']
    adata_D = adata_ct[adata_ct.obs['Condition'] == 'dengue']
    # while calculating ks test pvalue, the adata is log1ped, so the argument log1p=2
    results[subct] = anndataks.compare(adata_D, adata_SD, log1p=2, mode='asymp') # log2_fold_change: adata_Sd vs adata_D

ks_res = pd.DataFrame([])
for subct in subcts:
    results[subct]['cell_subtype'] = [subct] * results[subct].shape[0]
    ks_res = pd.concat([ks_res, results[subct]])

ks_res.set_index(['cell_subtype', ks_res.index], inplace=True)
ks_res.to_csv(save_tables + 'ks_pvalue.tsv', sep='\t')
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# ...

# %%
ks_res = pd.read_csv(save_tables + 'ks_pvalue.tsv', sep='\t', index_col=['cell_subtype', 'Unnamed: 1'])
ct_pair = pd.concat([ct_pair, ks_res.loc[ct_pair.index][['statistic', 'pvalue']]], axis=1)
ct_pair.to_csv(save_tables + 'ct_pair.tsv', sep='\t')

cst_pair = pd.concat([cst_pair, ks_res.loc[cst_pair.index][['statistic', 'pvalue']]], axis=1)
cst_pair = cst_pair.reset_index()
cst_pair['cell_subtype'] = cst_pair['cell_subtype'].replace({'plasmacytoid DCs': 'pDCs'})
cst_pair.to_csv(save_tables + 'cst_pair.tsv', sep='\t')

# %% [markdown]
# # adults

# %%
adata_adult = subsetdata(adata, platform ='plate')
adata_adult = normalizedata(adata_adult)
adata_adult = removegenes(adata_adult)

adata_adult = annanote_adult(adata_adult)
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# ...

# %%
# #pair comparison generation for cell types of kids 
cts = ['T cells', 'NK cells', 'B cells', 'Monocytes', 'cDCs', 'pDCs', 'Plasmablasts']

pair = pair_comparison(adata_adult, 'cell_type_new', cts, gene_cut_off=False, log1p=2)

pair['pair_res'].to_csv(save_tables + 'adult_ct_pair.tsv', sep='\t', index=False)
pair['log_FCs'].to_csv(save_tables + 'adult_ct_log2FC.tsv', sep='\t')

fra_av = fra_avg(adata_adult, cts, log1p=2)
fra_av['fra'].to_csv(save_tables + 'adult_ct_fra.tsv', sep='\t', index=False)
fra_av['avg'].to_csv(save_tables + 'adult_ct_avg.tsv', sep='\t', index=False)

data = combination(pair['pair_res'], fra_av['fra'], fra_av['avg'])
data.to_csv(save_tables + 'adult_ct_pair.tsv', sep='\t')
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# ...

# %%
csts = ['cytotoxic NK cells', 'signaling NK cells', 'proliferating plasmablasts', 'non-proliferating plasmablasts']

pair = pair_comparison(adata_adult, 'cell_subtype_new', csts, gene_cut_off=False, log1p=2)

pair['pair_res'].to_csv(save_tables + 'adult_cst_pair.tsv', sep='\t', index=False)
pair['log_FCs'].to_csv(save_tables + 'adult_cst_log2FC.tsv', sep='\t')

fra_av = fra_avg(adata_adult, csts, log1p=2)
fra_av['fra'].to_csv(save_tables + 'adult_cst_fra.tsv', sep='\t', index=False)
fra_av['avg'].to_csv(save_tables + 'adult_cst_avg.tsv', sep='\t', index=False)

data = combination(pair['pair_res'], fra_av['fra'], fra_av['avg'])
data.to_csv(save_tables + 'adult_cst_pair.tsv', sep='\t')
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# ...
