# %%
'''
Date: 8/Jan/2023
Auther: Yike Xie
Content: Exclude patient 1_075_01, get basic information of pairwise comparison
'''
# Out:
# '\nDate: 8/Jan/2023\nAuther: Yike Xie\nContent: Exclude patient 1_075_01, get basic information of pairwise comparison\n'

# %% [markdown]
# # DEGs of megakaryocytes

# %%
import os

import numpy as np
import pandas as pd

import anndata
import scanpy as sc

from collections import defaultdict
import anndataks
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
save_tables = '/home/yike/phd/dengue/docs/paper_draft/tabels/exclude_1_075_01/'

# %%
import sys
sys.path.append('/home/yike/phd/dengue/dengue_children/paper_figures/final/modules') 
import YK_util, optimized_pair_comparison, functions_CCC_figure_fra_pair
from YK_util import *
from optimized_pair_comparison import *
from functions_CCC_figure_fra_pair import *

# %%
path = '/home/yike/phd/dengue/data/mergedata_luca_NKT_202206.h5ad'
adata = sc.read_h5ad(path)
adata_kid = subsetdata(adata)
adata_kid = normalizedata(adata_kid, log1p=True) # log1p = 2
adata_kid = removegenes(adata_kid)
adata_kid = adata_kid[(adata_kid.obs.cell_subtype_new != 'doublets') & 
                        (adata_kid.obs.cell_subtype_new != 'unknown')].copy()

sc.pp.filter_genes(adata_kid, min_cells=3)

adata_kid = adata_kid[~ (adata_kid.obs['ID'] == '1_075_01')]
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)

# %%
#rename and reorder some celltypes 
adata_kid = adata_kid.copy()
reorg_data(adata_kid) # 'cell_type_new', 'cell_subtype_new'
# Out:
# /home/yike/phd/dengue/dengue_children/paper_figures/final/modules/YK_util.py:172: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   adata.obs['cell_type_new'].cat.reorder_categories(group_order_primary, inplace=True)
# /home/yike/phd/dengue/dengue_children/paper_figures/final/modules/YK_util.py:204: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   adata.obs['cell_subtype_new'].cat.reorder_categories(group_order_secondary, inplace=True)

# %%
ct_obs = 'cell_type_new'
cd_SD = ['S_dengue']
cd_D = ['dengue']
cell_types = [[i] for i in adata_kid.obs['cell_type_new'].unique().tolist()]

pair_res = pair_comparison(adata_kid, ct_obs, 
                           cd_SD, cd_D, 
                           cell_types, gene_cut_off=False, log1p=2)

pair_res['pair_res']['cell_subtype'] = pair_res['pair_res']['cell_subtype'].str.rstrip('_')
pair_res['log_FCs'].index = pair_res['log_FCs'].index.str.rstrip('_')

pair_res['pair_res'].to_csv(save_tables +  'ct_pair.tsv')
pair_res['log_FCs'].to_csv(save_tables + 'ct_log2FC.tsv')
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# ...

# %%
# combine pairwise comparison with fra and avg
ct_obs = 'cell_type_new'
cts = adata_kid.obs['cell_type_new'].unique().tolist()
cds = {'SD': ['S_dengue'], 'N': ['dengue']}

fra_avg = fra_avg(adata_kid, ct_obs, cts, cds, log1p=2)

fra_avg['fra'].to_csv(save_tables + 'ct_fra.tsv', sep='\t', index=False)
fra_avg['avg'].to_csv(save_tables + 'ct_avg.tsv', sep='\t', index=False)

pair = combination(pair_res['pair_res'], fra_avg['fra'], fra_avg['avg'])
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# ...

# %%
# ks test to get log2 fold change

ct_obs = 'cell_type_new'
cts = adata_kid.obs['cell_type_new'].unique().tolist()
cd_SD = ['S_dengue']
cd_D = ['dengue']
ks_res = ks(adata_kid, cts, ct_obs, cd_SD, cd_D, log1p=2)
ks_res = ks_res.reset_index().set_index(['cell_type', 'gene'])

pair = pd.concat([pair, ks_res.loc[pair.index][['log2_fold_change', 'statistic', 'pvalue']]], axis=1)
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# ...

# %%
# adjust pvalue

from statsmodels.stats.multitest import multipletests

cts = adata_kid.obs['cell_type_new'].unique().tolist()

ct_data = pd.DataFrame([])
for cell_type in cts:
    data_ct = pair.loc[cell_type]
    adjust_pvalue = multipletests(data_ct['pvalue'], alpha=0.05, method='fdr_bh')[1] # pvals_corrected
    data_ct['pvalue_corrected'] = adjust_pvalue
    data_ct['cell_subtype'] = cell_type
    data_ct.reset_index(inplace=True)
    ct_data = pd.concat([ct_data, data_ct])
    
    
ct_data.to_csv(save_tables + 'ct_pairwise_SD_vs_D.tsv', sep='\t', index=False)
# Out:
# <ipython-input-42-47ecf0ff9b9f>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ct['pvalue_corrected'] = adjust_pvalue
# <ipython-input-42-47ecf0ff9b9f>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ct['cell_subtype'] = cell_type
# <ipython-input-42-47ecf0ff9b9f>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
ct_obs = 'cell_subtype_new'
cd_SD = ['S_dengue']
cd_D = ['dengue']
cell_types = [[i] for i in adata_kid.obs['cell_subtype_new'].unique().tolist()]

pair_res = pair_comparison(adata_kid, ct_obs, 
                           cd_SD, cd_D, 
                           cell_types, gene_cut_off=False, log1p=2)

pair_res['pair_res']['cell_subtype'] = pair_res['pair_res']['cell_subtype'].str.rstrip('_')
pair_res['log_FCs'].index = pair_res['log_FCs'].index.str.rstrip('_')

pair_res['pair_res'].to_csv(save_tables +  'cst_pair.tsv')
pair_res['log_FCs'].to_csv(save_tables + 'cst_log2FC.tsv')
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# ...

# %%
def fra_avg(adata, ct_obs, cell_types, cds, log1p=False):    

    fra = pd.DataFrame([])
    avg = pd.DataFrame([])


    adata_cd = {cd: (adata[adata.obs['Condition'].isin(cd_ls)]) for cd, cd_ls in cds.items()}

    for cell_type in cell_types:
        for cd in cds:
            if cell_type not in adata_cd[cd].obs[ct_obs].unique():
                continue
            adata_ct = adata_cd[cd][adata_cd[cd].obs[ct_obs] == cell_type]
            
            if adata_ct.obs.shape[0] == 0:
                continue
            fra_ct = np.asarray((adata_ct.X > 0).mean(axis=0))[0]
            fra_ct = pd.DataFrame(fra_ct, columns=['fra'], index=adata_ct.var_names)
            fra_ct[ct_obs] = cell_type
            fra_ct['condition'] = cd
            fra = pd.concat([fra, fra_ct])
            fra['gene'] = fra.index.tolist()

            avg_ct = np.asarray(adata_ct.X.mean(axis=0))[0]
                        
            if log1p == 2:
                avg_ct = np.exp2(avg_ct) -1
            elif log1p not in (True, 2):
                avg_ct = np.exp2(np.log2(log1p) * avg_ct) - 1

            avg_ct = pd.DataFrame(avg_ct, columns=['avg'], index=adata_ct.var_names)
            avg_ct[ct_obs] = cell_type
            avg_ct['condition'] = cd
            avg = pd.concat([avg, avg_ct])
            avg['gene'] = avg.index.tolist()
            
    return {'fra': fra, 'avg': avg}

# %%
# combine pairwise comparison with fra and avg
ct_obs = 'cell_subtype_new'
cts = adata_kid.obs['cell_subtype_new'].unique().tolist()
cds = {'SD': ['S_dengue'], 'N': ['dengue']}

fra_avg = fra_avg(adata_kid, ct_obs, cts, cds, log1p=2)

fra_avg['fra'].to_csv(save_tables + 'cst_fra.tsv', sep='\t', index=False)
fra_avg['avg'].to_csv(save_tables + 'cst_avg.tsv', sep='\t', index=False)

pair = combination(pair_res['pair_res'], fra_avg['fra'], fra_avg['avg'])

# %%
# ks test to get log2 fold change

ct_obs = 'cell_subtype_new'
cts = adata_kid.obs['cell_subtype_new'].unique().tolist()
cd_SD = ['S_dengue']
cd_D = ['dengue']
ks_res = ks(adata_kid, cts, ct_obs, cd_SD, cd_D, log1p=2)
ks_res = ks_res.reset_index().set_index(['cell_type', 'gene'])

pair = pd.concat([pair, ks_res.loc[pair.index][['log2_fold_change', 'statistic', 'pvalue']]], axis=1)
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# ...

# %%
# adjust pvalue

from statsmodels.stats.multitest import multipletests

cts = adata_kid.obs['cell_subtype_new'].unique().tolist()

ct_data = pd.DataFrame([])
for cell_type in cts:
    data_ct = pair.loc[cell_type]
    adjust_pvalue = multipletests(data_ct['pvalue'], alpha=0.05, method='fdr_bh')[1] # pvals_corrected
    data_ct['pvalue_corrected'] = adjust_pvalue
    data_ct['cell_subtype'] = cell_type
    data_ct.reset_index(inplace=True)
    ct_data = pd.concat([ct_data, data_ct])
    
    
ct_data.to_csv(save_tables + 'cst_pairwise_SD_vs_D.tsv', sep='\t', index=False)
# Out:
# <ipython-input-54-aaf0acc5339c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ct['pvalue_corrected'] = adjust_pvalue
# <ipython-input-54-aaf0acc5339c>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ct['cell_subtype'] = cell_type
# <ipython-input-54-aaf0acc5339c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
