# %%
import numpy as np
import pandas as pd
import anndata
import scanpy as sc

# %%
import sys
sys.path.append('/home/yike/phd/dengue/dengue_children/paper_figures/final/modules') 
import YK_util, optimized_pair_comparison, functions_CCC_figure_fra_pair
from YK_util import *
from optimized_pair_comparison import *
from functions_CCC_figure_fra_pair import *

# %%
# load data
path = '/home/yike/phd/dengue/data/mergedata_luca_NKT_202206.h5ad'
adata = sc.read_h5ad(path)
adata_kid = subsetdata(adata)
adata_kid = normalizedata(adata_kid, log1p=True) # log1p = 2
adata_kid = removegenes(adata_kid)
adata_kid = adata_kid[(adata_kid.obs.cell_subtype_new != 'doublets') & 
                        (adata_kid.obs.cell_subtype_new != 'unknown')].copy()

sc.pp.filter_genes(adata_kid, min_cells=3)
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)

# %%
#rename and reorder some celltypes 
adata_kid = adata_kid.copy()
reorg_data(adata_kid) # 'cell_type_new', 'cell_subtype_new'
# Out:
# /home/yike/phd/dengue/dengue_children/paper_figures/final/modules/YK_util.py:172: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   adata.obs['cell_type_new'].cat.reorder_categories(group_order_primary, inplace=True)
# /home/yike/phd/dengue/dengue_children/paper_figures/final/modules/YK_util.py:204: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   adata.obs['cell_subtype_new'].cat.reorder_categories(group_order_secondary, inplace=True)

# %%
save_tables = '/home/yike/phd/dengue/docs/paper_draft/tabels/'
cell_types = adata_kid.obs['cell_type_new'].unique().tolist()
cell_subtypes = adata_kid.obs['cell_subtype_new'].unique().tolist()

# %%
ct_obs='cell_subtype_new'
cd_SD=['S_dengue', 'Dengue', 'DWS']
cd_D=['Healthy']

pair_res = pair_comparison(adata_kid, ct_obs, 
                           cd_SD, cd_D, 
                           [[ct] for ct in cell_subtypes], gene_cut_off=False, log1p=2)

pair_res['pair_res']['cell_subtype'] = pair_res['pair_res']['cell_subtype'].str.rstrip('_')
pair_res['pair_res'].to_csv(save_tables + 'sick_vs_healthy/' + 'sick_pair.tsv', sep='\t')

pair_res['log_FCs'].index = pair_res['log_FCs'].index.str.rstrip('_')
pair_res['log_FCs'].to_csv(save_tables + 'sick_vs_healthy/' + 'sick_log2FC.tsv', sep='\t')
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1095: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   df_sub[k].cat.remove_unused_categories(inplace=True)

# %%
pair_res['pair_res'].loc['FCGR1A']
# Out:
#         med_pair  fra_pair  neg_fra_pair                    cell_subtype  \
# FCGR1A  0.000000  0.333333      0.166667                   naive B cells
# FCGR1A  0.000000  0.395833      0.166667              cytotoxic NK cells
# FCGR1A  0.000000  0.181818      0.000000             CD4+ memory T cells
# FCGR1A  0.000000  0.090909      0.000000              signaling NK cells
# FCGR1A  0.000000  0.090909      0.000000                            MAIT
# FCGR1A  0.000000  0.090909      0.000000              CD8+ naive T cells
# FCGR1A  4.547777  1.000000      0.000000          intermediate monocytes
# FCGR1A  0.000000  0.181818      0.000000              CD4+ naive T cells
# FCGR1A  2.232208  0.725000      0.250000         non-classical monocytes
# FCGR1A  0.000000  0.000000      0.000000    CD8+ effector memory T cells
# FCGR1A  0.000000  0.166667      0.000000  non-proliferating plasmablasts
# FCGR1A  0.000000  0.166667      0.000000      proliferating plasmablasts
# FCGR1A  0.000000  0.000000      0.000000                            pDCs
# FCGR1A  0.363152  0.500000      0.000000                            cDC1
# FCGR1A  2.317172  0.791667      0.208333             classical monocytes
# FCGR1A  0.000000  0.000000      0.000000                  memory B cells
# FCGR1A  0.000000  0.181818      0.000000               activated B cells
# FCGR1A  3.251253  1.000000      0.000000                            cDC2
# FCGR1A  0.000000  0.000000      0.000000          CD8+ exhausted T cells
# FCGR1A  0.000000  0.000000      0.000000                           Tregs
# FCGR1A  0.000000  0.000000      0.000000                  megakaryocytes
#
#           gene
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A
# FCGR1A  FCGR1A

# %%
pair_res['pair_res'].loc['FCGR2A']
# Out:
#         med_pair  fra_pair  neg_fra_pair                    cell_subtype  \
# FCGR2A  0.012990  0.604167      0.395833                   naive B cells
# FCGR2A -0.002884  0.458333      0.541667              cytotoxic NK cells
# FCGR2A  0.000000  0.000000      0.000000             CD4+ memory T cells
# FCGR2A  0.000000  0.090909      0.227273              signaling NK cells
# FCGR2A -0.030561  0.090909      0.500000                            MAIT
# FCGR2A -0.007085  0.000000      0.500000              CD8+ naive T cells
# FCGR2A  3.845502  1.000000      0.000000          intermediate monocytes
# FCGR2A  0.000000  0.181818      0.000000              CD4+ naive T cells
# FCGR2A  0.941375  0.675000      0.325000         non-classical monocytes
# FCGR2A  0.000000  0.083333      0.000000    CD8+ effector memory T cells
# FCGR2A  0.000000  0.458333      0.375000  non-proliferating plasmablasts
# FCGR2A  0.058689  0.583333      0.000000      proliferating plasmablasts
# FCGR2A  0.000000  0.166667      0.000000                            pDCs
# FCGR2A  0.000000  0.200000      0.000000                            cDC1
# FCGR2A -0.549555  0.395833      0.604167             classical monocytes
# FCGR2A  0.000000  0.181818      0.000000                  memory B cells
# FCGR2A  0.025865  0.545455      0.272727               activated B cells
# FCGR2A  0.618459  0.600000      0.400000                            cDC2
# FCGR2A  0.000000  0.300000      0.000000          CD8+ exhausted T cells
# FCGR2A  0.000000  0.000000      0.000000                           Tregs
# FCGR2A  1.342961  0.600000      0.000000                  megakaryocytes
#
#           gene
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
# FCGR2A  FCGR2A
