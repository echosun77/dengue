# %%
# %config Completer.use_jedi = False
import numpy as np
import pandas as pd

import scanpy as sc

import matplotlib.pyplot as plt
import seaborn as sns

import anndata

adata_children=sc.read_h5ad('/home/yike/phd/dengue/data/write/umap_child.h5ad')
adata_adults=sc.read_h5ad('/home/yike/phd/dengue/data/write/umap_adult.h5ad')

# %%
#fn_h5ad = '/home/yike/phd/dengue/data/mergedata_new_ct_3_3_2021.h5ad'
#adata = anndata.read_h5ad(fn_h5ad)
#adata = adata[adata.obs['cell_quality'] == 'high']

#sc.pp.normalize_total(adata, target_sum=1e6) #normalize data to CPM (counts per million)
#sc.pp.log1p(adata)

#adata_children=adata[adata.obs['platform']=='10X']
#adata_adults=adata[adata.obs['platform']=='plate']

#results_children = '/home/yike/phd/dengue/data/write/umap_child.h5ad'
#results_adults = '/home/yike/phd/dengue/data/write/umap_adult.h5ad'

#sc.pp.pca(adata_children)
#sc.pp.neighbors(adata_children)
#sc.tl.umap(adata_children)
#adata_children.write(results_children)

#sc.pp.pca(adata_adults)
#sc.pp.neighbors(adata_adults)
#sc.tl.umap(adata_adults)
#adata_children.write(results_adults)
# Out:
# /home/yike/.conda/envs/scanpy/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:138: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
cell_types = list(adata_children.obs['cell_type'].astype('category').cat.categories)

from collections import defaultdict
adata_ad = {}
adata_ch = {}

for cell_type in cell_types:
    adata_ad[cell_type] = adata_adults[adata_adults.obs['cell_type'] == cell_type]
    adata_ch[cell_type] = adata_children[adata_children.obs['cell_type'] == cell_type]

# %%
sc.pl.umap(adata_ad['Monocytes'], color=['CD70', 'DPP4', 'cell_type'])

# %%
sc.pl.umap(adata_children, color=['DPP4', 'CXCL10', 'CXCR3', 'cell_type', 'Condition'], ncols=3)

# %%
sc.pl.umap(adata_children, color=['ITGA1', 'ITGA10', 'ITGB2', 'cell_type'], ncols=2)
